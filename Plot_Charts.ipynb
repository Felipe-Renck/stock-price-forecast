# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df1 = pd.read_csv('./data/[ADJUSTED] SAP Dataset 2016-2021 - XETRA EUR.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
df2 = pd.read_csv('./data/[ADJUSTED] EURO x BRL 2016-2021.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# Out:
# C:\Users\I514609\AppData\Local\Temp\ipykernel_32252\1858798445.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df1 = pd.read_csv('./data/[ADJUSTED] SAP Dataset 2016-2021 - XETRA EUR.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# C:\Users\I514609\AppData\Local\Temp\ipykernel_32252\1858798445.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df2 = pd.read_csv('./data/[ADJUSTED] EURO x BRL 2016-2021.csv', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
df1["Close"].head()
# Out:
# Date
# 2016-01-04    70.580002
# 2016-01-05    71.430000
# 2016-01-06    72.050003
# 2016-01-07    71.339996
# 2016-01-08    71.050003
# Name: Close, dtype: float64

# %%
df2["Close"].head()
# Out:
# Date
# 2016-01-04    4.2891
# 2016-01-05    4.3710
# 2016-01-06    4.3301
# 2016-01-07    4.3322
# 2016-01-08    4.4145
# Name: Close, dtype: float64

# %%
df2["Close"].plot()
plt.xlabel('Ano')
plt.ylabel('Preço (EUR)')
plt.title("Cotação EURO x Ano")
plt.grid(axis = 'y')
plt.show()
plt.savefig('EURO x Ano.png')

# %%
df1["Close"].plot()
plt.xlabel('Ano')
plt.ylabel('Preço (EUR)')
plt.title("Preço SAP:SE x Ano")
plt.grid(axis = 'y')
plt.show()
plt.savefig('SAP_SE x Ano.png')
